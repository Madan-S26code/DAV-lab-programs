# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("IRIS.csv")

# Seaborn plots
sns.histplot(df["petal-length"])
sns.histplot(df["sepal-length"])
plt.title("Petal Length and Sepal Length Histogram")
plt.show()

sns.boxplot(data=df[["sepal-length", "sepal-width", "petal-length", "petal-width"]])
plt.title("Box Plot of All Iris Features")
plt.show()

sns.scatterplot(data=df, x="sepal-length", y="petal-length", hue="species")
plt.title("Sepal Length and Petal Length by Species")
plt.show()

sns.pairplot(df, hue="species")
plt.show()

correlation = df[["sepal-length", "sepal-width", "petal-length", "petal-width"]].corr()
sns.heatmap(correlation, annot=True)
plt.title("Correlation of Iris Features")
plt.show()

# Matplotlib plots
plt.subplot(1, 2, 1)
plt.hist(df["petal-length"], bins=10)
plt.title("Petal Length")

plt.subplot(1, 2, 2)
plt.hist(df["sepal-length"], bins=10)
plt.title("Sepal Length")
plt.show()

plt.boxplot([df["sepal-length"], df["sepal-width"], df["petal-length"], df["petal-width"]], tick_labels=["Sepal Length", "Sepal Width", "Petal Length", "Petal Width"])
plt.title("Box Plot of All Iris Features")
plt.show()

plt.scatter(df["sepal-length"], df["petal-length"])
plt.title("Sepal Length and Petal Length")
plt.show()

pd.plotting.scatter_matrix(df[["sepal-length", "sepal-width", "petallength", "petal_width"]])
plt.show()

plt.matshow(correlation)
plt.xticks(range(4), correlation.columns)
plt.yticks(range(4), correlation.columns)
plt.title("Correlation of Iris Features")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 13
#       9 sns.histplot(df["sepal-length"])
#      10 plt.title("Petal Length and Sepal Length Histogram")
#      11 plt.show()
#      12
# ---> 13 sns.boxplot(data=df[["sepal_length", "sepal_width", "petal_length", "petal_width"]])
#      14 plt.title("Box Plot of All Iris Features")
#      15 plt.show()
#      16
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# ...
